# %%
#Importing all Required Libraries
import numpy as np
import pandas as pd
import string
from nltk.corpus import stopwords
import spacy
import warnings
warnings.filterwarnings('ignore')
import os

# %%
folder = os.fsencode("Reviews")
#Declaring a list which contains the filenames of all the files in that directory
filenames = []
#Traversing the folder, and appending all the files that ends with csv, to the list
for file in os.listdir(folder):
    filename = os.fsdecode(file)
    if filename.endswith( ('.csv') ):
        filenames.append(filename)

# %%
display(filenames)
# Out:
# ['1-800-Missing.csv',
#  '10 Cloverfield Lane.csv',
#  '1000-lb Sisters.csv',
#  '10x10.csv',
#  '11.22.63.csv',
#  '12 Mighty Orphans.csv',
#  '12 Years a Slave.csv',
#  '13 Going on 30.csv',
#  '13 Hours.csv',
#  '14 Peaks Nothing Is Impossible.csv',
#  '1492 Conquest of Paradise.csv',
#  '1883.csv',
#  '19-2.csv',
#  '1917.csv',
#  '1923.csv',
#  '2 Broke Girls.csv',
#  '2 Days in the Valley.csv',
#  '2 Fast 2 Furious.csv',
#  '2 Hearts.csv',
#  '2012.csv',
#  '21 Bridges.csv',
#  '24.csv',
#  '3 Days to Kill.csv',
#  '3 from Hell.csv',
#  '3 Idiots.csv',
#  '30 Monedas.csv',
#  '45 Years.csv',
#  '47 Meters Down Uncaged.csv',
#  '47 Meters Down.csv',
#  '47 Ronin.csv',
#  '6 Underground.csv',
#  '7 Days in Hell.csv',
#  '8 Mile.csv',
#  '8 Out of 10 Cats Does Countdown.csv',
#  '88 Minutes.csv',
#  '892.csv',
#  '8MM.csv',
#  '9-1-1 Lone Star.csv',
#  '9.csv',
#  '90 Day Fiancé.csv',
#  '90210.csv',
#  '99 Homes.csv',
#  'A Beautiful Day in the Neighborhood.csv',
#  'A Bigger Splash.csv',
#  "A Bug's Life.csv",
#  'A Castle for Christmas.csv',
#  'A Christmas Carol.csv',
#  'A Cure for Wellness.csv',
#  'A Dangerous Method.csv',
#  'A Discovery of Witches.csv',
#  'A Fall from Grace.csv',
#  'A Few Good Men.csv',
#  'A Friend of the Family.csv',
#  'A House on the Bayou.csv',
#  'A kaito.csv',
#  "A Knight's Tale.csv",
#  'A League of Their Own.csv',
#  'A Man Called Otto.csv',
#  'A Mighty Wind.csv',
#  'A Million Little Pieces.csv',
#  'A Most Violent Year.csv',
#  'A Quiet Place Part II.csv',
#  'A Quiet Place.csv',
#  'A Rainy Day in New York.csv',
#  'A River Runs Through It.csv',
#  'A Series of Unfortunate Events.csv',
#  'A Simple Plan.csv',
#  'A Teacher.csv',
#  'A Time to Kill.csv',
#  'A Very Brady Sequel.csv',
#  'A West Wing Special to Benefit When We All Vote.csv',
#  "A Wife's Nightmare.csv",
#  'A.I. Artificial Intelligence.csv',
#  'About a Boy.csv',
#  'About Fate.csv',
#  'About Time.csv',
#  'Above Suspicion.csv',
#  'Absentia.csv',
#  'Accident Man 2.csv',
#  'Ace Ventura When Nature Calls.csv',
#  'Acts of Violence.csv',
#  'Ad Astra.csv',
#  'Adaptation..csv',
#  'Addams Family Values.csv',
#  'After Life.csv',
#  'After Porn Ends.csv',
#  'After Yang.csv',
#  'After.csv',
#  "Agatha Christie's Marple.csv",
#  'Agents of S.H.I.E.L.D..csv',
#  'Agora.csv',
#  'Air America.csv',
#  'Air Force One.csv',
#  'Ajeossi.csv',
#  'Alcarràs.csv',
#  'Ali.csv',
#  'Alice in Wonderland.csv',
#  'Alice Through the Looking Glass.csv',
#  'Alice, Darling.csv',
#  'Aliens Abducted My Parents and Now I Feel Kinda Left Out.csv',
#  'Aliens in the Attic.csv',
#  'All American.csv',
#  'All Good Things.csv',
#  'All That.csv',
#  'All the Beauty and the Bloodshed.csv',
#  'All the Boys Love Mandy Lane.csv',
#  'All the Money in the World.csv',
#  'All the Pretty Horses.csv',
#  "All the Queen's Men.csv",
#  'Allegiant.csv',
#  'Alleyn Mysteries.csv',
#  'Allied.csv',
#  'Ally McBeal.csv',
#  'Along Came Polly.csv',
#  'Ambulance.csv',
#  'American Animals.csv',
#  'American Beauty.csv',
#  'American Crime Story.csv',
#  'American Crime.csv',
#  'American Gods.csv',
#  'American History X.csv',
#  'American Horror Stories.csv',
#  'American Hustle.csv',
#  'American Pie.csv',
#  'American Ultra.csv',
#  'American Underdog.csv',
#  'Amy.csv',
#  'An Amish Sin.csv',
#  'An Cailín Ciúin.csv',
#  'And Just Like That....csv',
#  'And Then There Were None.csv',
#  'Andor.csv',
#  'Angel Has Fallen.csv',
#  'Anger Management.csv',
#  'Animal Kingdom.csv',
#  "Anne Rice's Mayfair Witches.csv",
#  'Anne.csv',
#  'Another 48 Hrs..csv',
#  'Antebellum.csv',
#  'Antichrist.csv',
#  'Apocalypto.csv',
#  'Appaloosa.csv',
#  'Aqua Teen Hunger Force.csv',
#  'Aquaman.csv',
#  'Arcane League of Legends.csv',
#  'Archer.csv',
#  'Archive.csv',
#  'Argentina, 1985.csv',
#  'Armageddon.csv',
#  'Army of the Dead.csv',
#  'Army of Thieves.csv',
#  'Arrested Development.csv',
#  'Arrow.csv',
#  'Ash vs Evil Dead.csv',
#  'Assassin Club.csv',
#  'Assault on Precinct 13.csv',
#  "At Eternity's Gate.csv",
#  'Atlantic Crossing.csv',
#  'Atomic Blonde.csv',
#  'Atonement.csv',
#  'Atypical.csv',
#  'Aurora Teagarden Mysteries.csv',
#  'Austin Powers in Goldmember.csv',
#  'Austin Powers International Man of Mystery.csv',
#  'Austin Powers The Spy Who Shagged Me.csv',
#  'Autopsy The Last Hours of.csv',
#  'Avatar The Last Airbender.csv',
#  'Avatar The Way of Water.csv',
#  'Avengers Age of Ultron.csv',
#  'Avengers Endgame.csv',
#  'Avengers Infinity War.csv',
#  'AVP Alien vs. Predator.csv',
#  'Babe.csv',
#  'Baby Mama.csv',
#  'Baby Ruby.csv',
#  'Babylon.csv',
#  'Bad Boys.csv',
#  'Bad Education.csv',
#  'Bad Moms.csv',
#  'Bad Samaritan.csv',
#  'Bad Teacher.csv',
#  'Bad Times at the El Royale.csv',
#  'Baegabondeu.csv',
#  'Bakjwi.csv',
#  'Ballet Shoes.csv',
#  'Band of Brothers.csv',
#  'Bandit.csv',
#  'Banshee.csv',
#  'Barefoot.csv',
#  'Barmageddon.csv',
#  'Barry.csv',
#  'Barton Fink.csv',
#  'Bastille Day.csv',
#  'Bates Motel.csv',
#  'Batman and Superman Battle of the Super Sons.csv',
#  'Batman Begins.csv',
#  'Batman Forever.csv',
#  'Batman The Animated Series.csv',
#  'Batman The Dark Knight Returns, Part 1.csv',
#  'Batman The Killing Joke.csv',
#  'Batman The Long Halloween, Part One.csv',
#  'Batman v Superman Dawn of Justice.csv',
#  'Batoru rowaiaru.csv',
#  'Battle Los Angeles.csv',
#  'Baywatch.csv',
#  'Be Cool, Scooby-Doo!.csv',
#  'Beast.csv',
#  'Beasts of No Nation.csv',
#  'Beautiful Boy.csv',
#  'Beautiful Girls.csv',
#  'Beauty and the Beast.csv',
#  'Becker.csv',
#  'Beckett.csv',
#  'Bed Rest.csv',
#  'Bedazzled.csv',
#  'Beethoven.csv',
#  'Before Midnight.csv',
#  'Before Sunrise.csv',
#  'Behind Enemy Lines.csv',
#  'Behind Her Eyes.csv',
#  'Behind the Candelabra.csv',
#  'Being Human.csv',
#  'Being Mary Jane.csv',
#  'Bel-Air.csv',
#  'Below Deck.csv',
#  'Below Her Mouth.csv',
#  'Ben 10 Ultimate Alien.csv',
#  'Bend It Like Beckham.csv',
#  'Bent.csv',
#  'Better Off Ted.csv',
#  'Between Two Ferns The Movie.csv',
#  'Beverly Hills Cop III.csv',
#  'Beverly Hills, 90210.csv',
#  'Big Daddy.csv',
#  'Big Fish.csv',
#  'Big Little Lies.csv',
#  'Big Love.csv',
#  'Big Mouth.csv',
#  'Big Sky River.csv',
#  'Bill & Ted Face the Music.csv',
#  'Billionaire Boys Club.csv',
#  'Billions.csv',
#  "Billy Lynn's Long Halftime Walk.csv",
#  'Billy the Kid.csv',
#  'Bird Box.csv',
#  'Birdman or (The Unexpected Virtue of Ignorance).csv',
#  'Birds of Prey and the Fantabulous Emancipation of One Harley Quinn.csv',
#  'Black and Blue.csv',
#  'Black Hawk Down.csv',
#  'Black Mafia Family.csv',
#  'Black Panther.csv',
#  'Black Snake Moan.csv',
#  'Black Snow.csv',
#  'Black Swan.csv',
#  'Blackbird.csv',
#  'Blade Runner 2049.csv',
#  'Blade.csv',
#  'Blank Check.csv',
#  'Blast from the Past.csv',
#  'Blaze.csv',
#  'Blended.csv',
#  'Blonde.csv',
#  'Blood & Treasure.csv',
#  'Blood Diamond.csv',
#  'Blood Work.csv',
#  'Bloodline.csv',
#  'Bloodshot.csv',
#  'Blossom.csv',
#  'Blue Bayou.csv',
#  'Blue Christmas.csv',
#  'Blue Heelers.csv',
#  'Blue Valentine.csv',
#  'Blueface & Chrisean Crazy in Love.csv',
#  'Bluey.csv',
#  'Boardwalk Empire.csv',
#  'Bob Hearts Abishola.csv',
#  "Bob's Burgers.csv",
#  'Bobby.csv',
#  'Bodies Bodies Bodies.csv',
#  'Body of Lies.csv',
#  'Bodyguard.csv',
#  'Bohemian Rhapsody.csv',
#  'Boiling Point.csv',
#  'BoJack Horseman.csv',
#  'Boku no hîrô akademia.csv',
#  'Bolt.csv',
#  'Bombshell.csv',
#  'Boogie.csv',
#  'Bosch Legacy.csv',
#  'Bosch.csv',
#  'Bottom.csv',
#  'Bound by Honor.csv',
#  'Boy Meets World.csv',
#  "Brad's Status.csv",
#  'Brahmastra Part One Shiva.csv',
#  'Brave.csv',
#  'Brawl in Cell Block 99.csv',
#  'Break Point.csv',
#  'Breaking Bad.csv',
#  'Breakout Kings.csv',
#  'Breeders.csv',
#  'Brick.csv',
#  'Bridge to Terabithia.csv',
#  'Bridgerton.csv',
#  'Bright.csv',
#  'Brimstone.csv',
#  'Broadchurch.csv',
#  'Brokeback Mountain.csv',
#  'Broken City.csv',
#  'Broken.csv',
#  'Bruce Almighty.csv',
#  'Buffy the Vampire Slayer.csv',
#  'Bullet Train.csv',
#  'Bully.csv',
#  'Bumblebee.csv',
#  'Burn After Reading.csv',
#  'Burnt.csv',
#  'Busanhaeng.csv',
#  'Cabin Boy.csv',
#  'Californication.csv',
#  'Call Me by Your Name.csv',
#  'Call Me Kat.csv',
#  'Call Me Miss Cleo.csv',
#  'Call of Duty Modern Warfare.csv',
#  'Call the Midwife.csv',
#  'Calls.csv',
#  'Calm with Horses.csv',
#  'Cam.csv',
#  'Camp Rock.csv',
#  'Cape Fear.csv',
#  'Captain America Civil War.csv',
#  'Captain America The First Avenger.csv',
#  'Captain America The Winter Soldier.csv',
#  'Captain Marvel.csv',
#  'Cargo.csv',
#  'Carnival Row.csv',
#  'Cars 2.csv',
#  'Case Histories.csv',
#  'Casino.csv',
#  'Casper.csv',
#  'Cast Away.csv',
#  'Castle Rock.csv',
#  'Castlevania.csv',
#  'Casual.csv',
#  'Central Intelligence.csv',
#  'Central Park.csv',
#  'Cerdita.csv',
#  'Chapelwaite.csv',
#  'Charlie and the Chocolate Factory.csv',
#  'Charlie St. Cloud.csv',
#  'Charmed.csv',
#  'Charming.csv',
#  'Chasing Mavericks.csv',
#  'Chef.csv',
#  'Chemistry of Death.csv',
#  'Cherry.csv',
#  'Chicago Med.csv',
#  'Chicago Party Aunt.csv',
#  'Chloe.csv',
#  'Chocolat.csv',
#  'Christmas with the Campbells.csv',
#  'Chuck.csv',
#  'Chucky.csv',
#  'Cinderella.csv',
#  'City Homicide.csv',
#  "Clarkson's Farm.csv",
#  'Clerks II.csv',
#  'Cliffhanger.csv',
#  'Clifton Hill.csv',
#  'Climax.csv',
#  'Close Enough.csv',
#  'Closer.csv',
#  'Cloud Atlas.csv',
#  'Clueless.csv',
#  'CODA.csv',
#  'Coherence.csv',
#  'Cold Case.csv',
#  'Cold Pursuit.csv',
#  'Colin in Black & White.csv',
#  'Collateral Beauty.csv',
#  'Colonia.csv',
#  'Colony.csv',
#  'Coneheads.csv',
#  'Confess, Fletch.csv',
#  'Contact.csv',
#  'Contagion.csv',
#  'Contratiempo.csv',
#  'Cool Runnings.csv',
#  'Cop Out.csv',
#  'Coraline.csv',
#  'Coroner.csv',
#  'Corsage.csv',
#  'Counterpart.csv',
#  'Country Comfort.csv',
#  'Couples Retreat.csv',
#  'Covert Affairs.csv',
#  'Cowboy Bebop Tengoku no tobira.csv',
#  'Coyote Ugly.csv',
#  'Crank High Voltage.csv',
#  'Crash.csv',
#  'Crazy, Stupid, Love..csv',
#  'Creed II.csv',
#  'Creed.csv',
#  'Crime.csv',
#  'Crimes of the Future.csv',
#  'Criminal Minds.csv',
#  'Criminal UK.csv',
#  'Crimson Tide.csv',
#  'Crisis.csv',
#  'Cruel Intentions.csv',
#  'Cruella.csv',
#  'CSI Crime Scene Investigation.csv',
#  'CSI NY.csv',
#  'CSI Vegas.csv',
#  'Cult of Chucky.csv',
#  'Cunk on Earth.csv',
#  'Curb Your Enthusiasm.csv',
#  'Curious George.csv',
#  'Daddy Day Care.csv',
#  "Daddy's Home 2.csv",
#  "Daddy's Home.csv",
#  'Dahmer - Monster The Jeffrey Dahmer Story.csv',
#  'Dallas Buyers Club.csv',
#  'Dalziel and Pascoe.csv',
#  'Damage.csv',
#  'Damsel.csv',
#  'Dan in Real Life.csv',
#  'Dances with Wolves.csv',
#  'Daredevil.csv',
#  'Dark Phoenix.csv',
#  'Dark Places.csv',
#  'Dark Shadows.csv',
#  'Darkest Hour.csv',
#  'DARLING in the FRANXX.csv',
#  'Date Night.csv',
#  'Daughters of Abdul-Rahman.csv',
#  'Dave.csv',
#  'Dawn of the Dead.csv',
#  'Dawn of the Planet of the Apes.csv',
#  'Day Shift.csv',
#  'Days of Thunder.csv',
#  'Dazed and Confused.csv',
#  'De ofrivilliga.csv',
#  'De slag om de Schelde.csv',
#  'Dead Presidents.csv',
#  'Deadpool 2.csv',
#  'Deadstream.csv',
#  'Deadwood.csv',
#  'Deal or No Deal.csv',
#  'Death on the Nile.csv',
#  'Death Parade.csv',
#  'Death Proof.csv',
#  'Death Race.csv',
#  'Death Sentence.csv',
#  'Defending Jacob.csv',
#  'Defiance.csv',
#  'Definitely, Maybe.csv',
#  'Degrassi Next Class.csv',
#  'Degrassi The Next Generation.csv',
#  'Deliver Us from Evil.csv',
#  'Den of Thieves.csv',
#  'Derry Girls.csv',
#  'Desperate Housewives.csv',
#  'Desperate Measures.csv',
#  'Despicable Me 3.csv',
#  'Detectorists.csv',
#  'Devil in a Blue Dress.csv',
#  'Devil in Ohio.csv',
#  'Devil in the Flesh.csv',
#  'Devilman Crybaby.csv',
#  'Dexter New Blood.csv',
#  'Dexter.csv',
#  'Dharma & Greg.csv',
#  'Diabolical.csv',
#  'Diagnosis Murder.csv',
#  'Diary of a Wimpy Kid Rodrick Rules.csv',
#  'Dickensian.csv',
#  'Die Another Day.csv',
#  'Died Suddenly.csv',
#  'Dinnerladies.csv',
#  'Dinosaurs.csv',
#  'Dirty Dancing Havana Nights.csv',
#  'Disenchanted.csv',
#  'Disney Dreamlight Valley.csv',
#  'Dispatches from Elsewhere.csv',
#  'District 9.csv',
#  'Disturbing Behavior.csv',
#  'Django Unchained.csv',
#  'Do Revenge.csv',
#  'Doc Martin.csv',
#  'Doctor Strange in the Multiverse of Madness.csv',
#  'Documentary Now!.csv',
#  'Dodgeball A True Underdog Story.csv',
#  'Dog Gone.csv',
#  'Dog.csv',
#  'Dollhouse.csv',
#  'Domina.csv',
#  'Domino.csv',
#  "Don't Breathe No Escape.csv",
#  "Don't Look Up.csv",
#  "Don't Say a Word.csv",
#  'Donde caben dos.csv',
#  'Donnie Brasco.csv',
#  'Donnie Darko.csv',
#  'Doomsday.csv',
#  'Door Mouse.csv',
#  'Dopesick.csv',
#  'Dorian Gray.csv',
#  'Doubt.csv',
#  'Down with Love.csv',
#  'Downsizing.csv',
#  'Downton Abbey.csv',
#  'Dracula Untold.csv',
#  'Dracula.csv',
#  'Dragon Age Absolution.csv',
#  'Dragon Ball Super Doragon bôru cho.csv',
#  'Dreamgirls.csv',
#  'Dreamland.csv',
#  'Dredd.csv',
#  'Drink Masters.csv',
#  'Drishyam 2.csv',
#  'Drive Me Crazy.csv',
#  'Drive.csv',
#  'Dronningen.csv',
#  'Drop Dead Diva.csv',
#  'Drunk History.csv',
#  'Dual.csv',
#  'Duck Dynasty.csv',
#  'DuckTales.csv',
#  "Dude, Where's My Car.csv",
#  'Dumb and Dumber To.csv',
#  'Dumb and Dumber.csv',
#  'Dumbo.csv',
#  "Dumplin'.csv",
#  'Dune.csv',
#  'Dying for Chocolate A Curious Caterer Mystery.csv',
#  'Dynasty.csv',
#  'Eagle Eye.csv',
#  'Early Doors.csv',
#  'East New York.csv',
#  'Eastbound & Down.csv',
#  'Easy A.csv',
#  'Echoes.csv',
#  'Ed, Edd n Eddy.csv',
#  'Eddie the Eagle.csv',
#  'Edge of Tomorrow.csv',
#  'Edward Scissorhands.csv',
#  'Efter brylluppet.csv',
#  'El mariachi.csv',
#  'Electric Dreams.csv',
#  'Elektra Luxx.csv',
#  'Elementary.csv',
#  'Elf.csv',
#  'Eliza Graves.csv',
#  'Elvis.csv',
#  'Emancipation.csv',
#  'Emily the Criminal.csv',
#  'Emma.csv',
#  'Empire Records.csv',
#  'Encanto.csv',
#  'Enchanted.csv',
#  'Encino Man.csv',
#  'Encounter.csv',
#  'Endeavour.csv',
#  'Enemy at the Gates.csv',
#  'Enemy of the State.csv',
#  'Enemy.csv',
#  'Enlightened.csv',
#  'Enola Holmes 2.csv',
#  'Enola Holmes.csv',
#  'Enter the Void.csv',
#  'Enterprise.csv',
#  'Entourage.csv',
#  'Eraser.csv',
#  'Escape from L.A..csv',
#  'Escape from Tomorrow.csv',
#  'Escape Room.csv',
#  'Eternal Sunshine of the Spotless Mind.csv',
#  'Eternals.csv',
#  'EuroTrip.csv',
#  'Evan Almighty.csv',
#  'Event Horizon.csv',
#  'Everest.csv',
#  'Everybody Hates Chris.csv',
#  'Everybody Loves Raymond.csv',
#  'Everyone Else Burns.csv',
#  'Everything Everywhere All at Once.csv',
#  'Everything Must Go.csv',
#  'Ex Machina.csv',
#  'Exam.csv',
#  'Exit.csv',
#  'Extinction.csv',
#  'Extraction.csv',
#  'Eye in the Sky.csv',
#  'Eyes Wide Shut.csv',
#  'F9.csv',
#  'Fallen.csv',
#  'Falling Down.csv',
#  'Falling for Christmas.csv',
#  'Family History Mysteries Buried Past.csv',
#  'Fantastic Beasts and Where to Find Them.csv',
#  'Fantastic Beasts The Crimes of Grindelwald.csv',
#  'Fantastic Beasts The Secrets of Dumbledore.csv',
#  'Fantasy Island.csv',
#  'Far from the Madding Crowd.csv',
#  'Faraway Eyes.csv',
#  'Farscape.csv',
#  'Fast & Furious Presents Hobbs & Shaw.csv',
#  'Fast & Furious.csv',
#  'Fate The Winx Saga.csv',
#  'Father Brown.csv',
#  'Father of the Bride.csv',
#  'Fathers & Daughters.csv',
#  'FBI Most Wanted.csv',
#  'FBI.csv',
#  'Fear and Loathing in Las Vegas.csv',
#  'Felicity.csv',
#  'Fences.csv',
#  'Ferdinand.csv',
#  'Feud.csv',
#  'Fever Pitch.csv',
#  'Fight Club.csv',
#  'Filth.csv',
#  'Final Destination 2.csv',
#  'Final Destination 3.csv',
#  'Final Space.csv',
#  'Firefly Lane.csv',
#  'Firefly.csv',
#  'Fires.csv',
#  'First Kill.csv',
#  'First Knight.csv',
#  'First Man.csv',
#  'Fish Tank.csv',
#  "Fisherman's Friends.csv",
#  'Five Feet Apart.csv',
#  'Flaked.csv',
#  'Flashforward.csv',
#  'Flashpoint.csv',
#  'Fleabag.csv',
#  'Flight of the Conchords.csv',
#  'Flowers.csv',
#  "Footballers' Wives.csv",
#  'For All Mankind.csv',
#  'For Your Consideration.csv',
#  'Forces of Nature.csv',
#  'Ford v Ferrari.csv',
#  'Forensic Files.csv',
#  'Forrest Gump.csv',
#  'Fortitude.csv',
#  'Foundation.csv',
#  'Four Weddings and a Funeral.csv',
#  'Frances Ha.csv',
#  'Frasier.csv',
#  'Free Guy.csv',
#  'Free Solo.csv',
#  'Fremont.csv',
#  'Fresh.csv',
#  'Frida.csv',
#  'Friday Night Lights.csv',
#  'Friday.csv',
#  'Fried Green Tomatoes.csv',
#  'Friends The Reunion.csv',
#  'Friends with Benefits.csv',
#  'From Dusk Till Dawn.csv',
#  'From Scratch.csv',
#  'From.csv',
#  'Fruits Basket.csv',
#  'Fury.csv',
#  'Futurama.csv',
#  'Future Man.csv',
#  'G.I. Jane.csv',
#  'Game of Thrones.csv',
#  'Gamer.csv',
#  'Gangs of London.csv',
#  'Gangs of New York.csv',
#  'Garfield.csv',
#  'Gargoyles.csv',
#  'Gaslit.csv',
#  'George & Tammy.csv',
#  'George of the Jungle.csv',
#  'Geostorm.csv',
#  "Gerald's Game.csv",
#  'Get Carter.csv',
#  'Get Out.csv',
#  'Gettysburg.csv',
#  'Ghost Adventures House Calls.csv',
#  'Ghost Ship.csv',
#  'Ghost Town.csv',
#  'Ghost Whisperer.csv',
#  'Ghost World.csv',
#  'Ghost.csv',
#  'Ghostbusters Afterlife.csv',
#  'Ghostbusters.csv',
#  'Ghosts of War.csv',
#  'Ghosts.csv',
#  'Gifted Hands The Ben Carson Story.csv',
#  'Ginny & Georgia.csv',
#  'Girl in the Basement.csv',
#  'Girl Meets World.csv',
#  'Girls.csv',
#  'Gisaengchung.csv',
#  'Gladiator.csv',
#  'Glass Onion.csv',
#  'Glass.csv',
#  'Glück.csv',
#  'Go-Toubun no Hanayome.csv',
#  'God of War Ragnarök.csv',
#  "God's Favorite Idiot.csv",
#  'Gods of Egypt.csv',
#  'Godzilla vs. Kong.csv',
#  'Godzilla.csv',
#  'Going in Style.csv',
#  'Gojira Fainaru uôzu.csv',
#  'Gold Rush White Water.csv',
#  'Gold Rush.csv',
#  'Goliath.csv',
#  'Gone Baby Gone.csv',
#  'Gone Girl.csv',
#  'Good Behavior.csv',
#  'Good Burger.csv',
#  'Good Kids.csv',
#  'Good Luck to You, Leo Grande.csv',
#  'Good Time.csv',
#  'Good Will Hunting.csv',
#  'Good Witch.csv',
#  'GoodFellas.csv',
#  'Goon.csv',
#  'Gossip Girl.csv',
#  'Gotham.csv',
#  'Grand Army.csv',
#  'Gravity.csv',
#  'Green Book.csv',
#  'Green Room.csv',
#  'Greenland.csv',
#  'Greyhound.csv',
#  'Grimm.csv',
#  'Grimsby.csv',
#  'Grind.csv',
#  'Grosse Pointe Blank.csv',
#  'Grown Ups 2.csv',
#  'Große Freiheit.csv',
#  'Grumpy Old Men.csv',
#  'Guardians of the Galaxy Vol. 2.csv',
#  'Guardians of the Galaxy.csv',
#  'Guarding Tess.csv',
#  'Gummo.csv',
#  'Gunpowder Milkshake.csv',
#  'Guy and Madeline on a Park Bench.csv',
#  'Habitación en Roma.csv',
#  'Hackers.csv',
#  'Hacks.csv',
#  'Hacksaw Ridge.csv',
#  'Hailey Dean Mystery.csv',
#  'Half Baked.csv',
#  'Hall Pass.csv',
#  'Halo.csv',
#  'Hancock.csv',
#  'Hands of Stone.csv',
#  'Hannah Montana.csv',
#  'Hannibal.csv',
#  'Hanyo.csv',
#  'Happiness.csv',
#  'Happy Feet Two.csv',
#  'Happy Feet.csv',
#  'Happy Gilmore.csv',
#  'Happy Valley.csv',
#  'Hard Target.csv',
#  'Harley Quinn.csv',
#  'Harlots.csv',
#  'Harrow.csv',
#  'Harry Potter and the Chamber of Secrets.csv',
#  'Harry Potter and the Deathly Hallows - Part 2.csv',
#  'Harry Potter and the Deathly Hallows Part 1.csv',
#  'Harry Potter and the Goblet of Fire.csv',
#  'Harry Potter and the Prisoner of Azkaban.csv',
#  'Haven.csv',
#  'Hawaii Five-0.csv',
#  'Hawkeye.csv',
#  'Heartbeat.csv',
#  'Heartbreak High.csv',
#  'Heartland.csv',
#  'Heartstopper.csv',
#  'Heat.csv',
#  'Heavenly Sword.csv',
#  'Hector and the Search for Happiness.csv',
#  'Hell or High Water.csv',
#  'Hellboy II The Golden Army.csv',
#  'Hellboy.csv',
#  'Hello, My Name Is Doris.csv',
#  'Help.csv',
#  'Hemlock Grove.csv',
#  'Henry & June.csv',
#  'Her.csv',
#  'Hercules.csv',
#  'Hidden Figures.csv',
#  'Hilary and Jackie.csv',
#  'Hilda.csv',
#  'Hillbilly Elegy.csv',
#  "Hitman's Wife's Bodyguard.csv",
#  'Holby City.csv',
#  'Hold the Dark.csv',
#  'Holidate.csv',
#  'Home Alone 2 Lost in New York.csv',
#  'Home Economics.csv',
#  'Home Movie The Princess Bride.csv',
#  'Homefront.csv',
#  'Homeland.csv',
#  'Honey Boy.csv',
#  'Honor Society.csv',
#  'Hoodlum.csv',
#  'Hoodwinked!.csv',
#  'Hoot.csv',
#  'Horizon Forbidden West.csv',
#  'Horton Hears a Who!.csv',
#  'Hot Fuzz.csv',
#  'Hot Shots! Part Deux.csv',
#  'Hot Shots!.csv',
#  'Hot Sluts.csv',
#  'Hot Summer Nights.csv',
#  'Hot Tub Time Machine.csv',
#  'Hotel Mumbai.csv',
#  'Hotel Portofino.csv',
#  'Hotel Transylvania 3 Summer Vacation.csv',
#  'Hounddog.csv',
#  'House of Cards.csv',
#  'House of Gucci.csv',
#  'House of Lies.csv',
#  'House Party.csv',
#  'Housebound.csv',
#  'How I Met Your Father.csv',
#  'How to Get Away with Murder.csv',
#  'How to Train Your Dragon.csv',
#  'How to with John Wilson.csv',
#  'Hudson & Rex.csv',
#  'Humans.csv',
#  'Hunters.csv',
#  'Hunting Hitler.csv',
#  'Huo Yuan Jia.csv',
#  'Hustle.csv',
#  'Hustlers.csv',
#  'Hyena Road.csv',
#  'Hypnotic.csv',
#  'I Am Number Four.csv',
#  'I Am Sam.csv',
#  'I Am the Night.csv',
#  'I Am....csv',
#  'I Came By.csv',
#  "I Can't Think Straight.csv",
#  'I Hate Suzie.csv',
#  'I Love My Dad.csv',
#  'I Spit on Your Grave.csv',
#  "I'm Dying Up Here.csv",
#  "I'm Not There.csv",
#  'I, Frankenstein.csv',
#  'I, Tonya.csv',
#  'iCarly.csv',
#  'Ice Age Dawn of the Dinosaurs.csv',
#  'Idiocracy.csv',
#  'Imperium.csv',
#  'In Bruges.csv',
#  'In from the Side.csv',
#  'In My Dreams.csv',
#  'In the Dark.csv',
#  'In the House.csv',
#  'In the Mouth of Madness.csv',
#  'Incendies.csv',
#  'Inception.csv',
#  'Indecent Proposal.csv',
#  'Independence Day.csv',
#  'Indiana Jones and the Kingdom of the Crystal Skull.csv',
#  'Infinity Pool.csv',
#  'Inglourious Basterds.csv',
#  'Inside Job.csv',
#  'Inside Man.csv',
#  'Inside Out.csv',
#  'Insidious Chapter 2.csv',
#  'Internal Affairs.csv',
#  'Interview with the Vampire.csv',
#  'Into the Forest.csv',
#  'Intolerable Cruelty.csv',
#  'Invincible.csv',
#  'Ip Man.csv',
#  'Iron Fist.csv',
#  'Iron Sky.csv',
#  'Irreverent.csv',
#  'It Chapter Two.csv',
#  'It.csv',
#  'Ivy & Bean.csv',
#  'iZombie.csv',
#  'Jack Frost.csv',
#  'Jack Irish.csv',
#  'Jack Reacher Never Go Back.csv',
#  'Jack Reacher.csv',
#  'Jack Ryan.csv',
#  'Jackass.csv',
#  'Jackie Brown.csv',
#  'JAG.csv',
#  'James and the Giant Peach.csv',
#  'Jamestown.csv',
#  'Jason Bourne.csv',
#  'Jawbreaker.csv',
#  "Jennifer's Body.csv",
#  'Jericho.csv',
#  'Jerry & Marge Go Large.csv',
#  'Jerry Maguire.csv',
#  'Jersey Boys.csv',
#  'Jessica Jones.csv',
#  'Joan of Arc.csv',
#  'Joe Dirt.csv',
#  'Joe Versus the Volcano.csv',
#  'John Wick Chapter 2.csv',
#  'John Wick Chapter 3 - Parabellum.csv',
#  'Johnny English Reborn.csv',
#  'Johnny English.csv',
#  'Joker.csv',
#  'Jonathan Creek.csv',
#  'Jongens.csv',
#  'Journey 2 The Mysterious Island.csv',
#  'Joy Ride.csv',
#  'Joyful Noise.csv',
#  'Judge Dredd.csv',
#  'Julie and the Phantoms.csv',
#  'Jumanji The Next Level.csv',
#  'Jumanji.csv',
#  'Jungle Cruise.csv',
#  'Jungle Fever.csv',
#  'Jungle.csv',
#  'Juno.csv',
#  'Jurassic Park.csv',
#  'Jurassic World.csv',
#  'Just Go with It.csv',
#  'Just Like Heaven.csv',
#  'Justice League.csv',
#  'Justified.csv',
#  'Kaleidoscope.csv',
#  'Kaçis.csv',
#  'Keeping Up Appearances.csv',
#  'Kicking and Screaming.csv',
#  'Kidding.csv',
#  'Kill Bill The Whole Bloody Affair.csv',
#  'Kill Your Darlings.csv',
#  'King Arthur Legend of the Sword.csv',
#  'King Kong.csv',
#  'King of the Hill.csv',
#  'King of Thieves.csv',
#  'King Richard.csv',
#  'Kingdom Business.csv',
#  'Kingdom of Heaven.csv',
#  'Kingsman The Secret Service.csv',
#  'Kiss the Girls.csv',
#  'Kitchen Nightmares.csv',
#  'Knight of Cups.csv',
#  'Knives Out.csv',
#  'Knocked Up.csv',
#  'Knowing.csv',
#  'Koala Man.csv',
#  'Kona fer í stríð.csv',
#  'Kung Fu Panda The Dragon Knight.csv',
#  'Kung Fu Panda.csv',
#  'Kyle XY.csv',
#  "L'apparition.csv",
#  "L'uomo che guarda.csv",
#  'La Brea.csv',
#  'La casa de papel.csv',
#  'La La Land.csv',
#  'La meglio gioventù.csv',
#  'La nuit a dévoré le monde.csv',
#  "La vie d'Adèle.csv",
#  'La vita è bella.csv',
#  'Ladies Man.csv',
#  'Lady and the Tramp.csv',
#  'Lady Bird.csv',
#  "Lady Chatterley's Lover.csv",
#  'Lamborghini The Man Behind the Legend.csv',
#  'Larry Crowne.csv',
#  'Lars and the Real Girl.csv',
#  'Last Looks.csv',
#  'Last Man Standing.csv',
#  'Last Night in Soho.csv',
#  'Last Night.csv',
#  'Last Seen Alive.csv',
#  'Law & Order Criminal Intent.csv',
#  'Law & Order Organized Crime.csv',
#  'Law Abiding Citizen.csv',
#  'Lawless.csv',
#  "Le fabuleux destin d'Amélie Poulain.csv",
#  'Le loup et le lion.csv',
#  'Leap Year.csv',
#  'Leaving Las Vegas.csv',
#  'Legally Blonde.csv',
#  'Legend of the Seeker.csv',
#  'Legend.csv',
#  'Legends of Tomorrow.csv',
#  'Lego Masters.csv',
#  'Les Misérables.csv',
#  'Lesbian Vampire Killers.csv',
#  'Let Him Go.csv',
#  'Lethal Weapon 4.csv',
#  'Lethal Weapon.csv',
#  'Letterkenny.csv',
#  ...]

# %%
length = len(filenames)
df = []

for i in range(length):
    f= pd.read_csv("Reviews//"+filenames[i])
    df.append(f)
    
s = pd.concat(df)

# %%
#Cnsidering only these 2 columns
data = s[['Rating','Review']].copy()

#Converting rating column from object to string
data['Rating'] = data['Rating'].astype('string')

#Droping all the Null values
data = data.dropna()

#Converting Rating to Numeric form for calculations
data['Rating'] = pd.to_numeric(data['Rating'])
#data["Rating"]=data["Rating"]/2
data['Rating']=data['Rating'].astype(int)
data
# Out:
#     Rating                                             Review
# 0        9  I've been a fan of The Walking Dead ever since...
# 1        9  I've been a fan of The Walking Dead ever since...
# 2        9  I would put this series my top 5 off all time ...
# 3        9  First thing I have to say is that I am normall...
# 4        9  Everyone know that The Walking Dead isn't as g...
# ..     ...                                                ...
# 20       8  Another beautiful and meaningful animation by ...
# 21       9  If you enjoy reading my Spoiler-Free reviews, ...
# 22       9  Joe voiced by Jamie Foxx is a jazz musician wh...
# 23      10  I never thought I would ever watch a film from...
# 24       9  I was lucky enough to see this at the London F...
#
# [52082 rows x 2 columns]

# %%
#Dictionary used for data Pre-Processing
apposV2 = {
"are not" : "are not",
"ca" : "can",
"could n't" : "could not",
"did n't" : "did not",
"does n't" : "does not",
"do n't" : "do not",
"had n't" : "had not",
"has n't" : "has not",
"have n't" : "have not",
"he'd" : "he would",
"he'll" : "he will",
"he's" : "he is",
"i'd" : "I would",
"i'd" : "I had",
"i'll" : "I will",
"i'm" : "I am",
"is n't" : "is not",
"it's" : "it is",
"it'll":"it will",
"i've" : "I have",
"let's" : "let us",
"might n't" : "might not",
"must n't" : "must not",
"sha" : "shall",
"she'd" : "she would",
"she'll" : "she will",
"she's" : "she is",
"should n't" : "should not",
"that's" : "that is",
"there's" : "there is",
"they'd" : "they would",
"they'll" : "they will",
"they're" : "they are",
"they've" : "they have",
"we'd" : "we would",
"we're" : "we are",
"were n't" : "were not",
"we've" : "we have",
"what'll" : "what will",
"what're" : "what are",
"what's" : "what is",
"what've" : "what have",
"where's" : "where is",
"who'd" : "who would",
"who'll" : "who will",
"who're" : "who are",
"who's" : "who is",
"who've" : "who have",
"wo" : "will",
"would n't" : "would not",
"you'd" : "you would",
"you'll" : "you will",
"you're" : "you are",
"you've" : "you have",
"'re": " are",
"was n't": "was not",
"we'll":"we will",
"did n't": "did not"
}
appos = {
"aren't" : "are not",
"can't" : "cannot",
"couldn't" : "could not",
"didn't" : "did not",
"doesn't" : "does not",
"don't" : "do not",
"hadn't" : "had not",
"hasn't" : "has not",
"haven't" : "have not",
"he'd" : "he would",
"he'll" : "he will",
"he's" : "he is",
"i'd" : "I would",
"i'd" : "I had",
"i'll" : "I will",
"i'm" : "I am",
"isn't" : "is not",
"it's" : "it is",
"it'll":"it will",
"i've" : "I have",
"let's" : "let us",
"mightn't" : "might not",
"mustn't" : "must not",
"shan't" : "shall not",
"she'd" : "she would",
"she'll" : "she will",
"she's" : "she is",
"shouldn't" : "should not",
"that's" : "that is",
"there's" : "there is",
"they'd" : "they would",
"they'll" : "they will",
"they're" : "they are",
"they've" : "they have",
"we'd" : "we would",
"we're" : "we are",
"weren't" : "were not",
"we've" : "we have",
"what'll" : "what will",
"what're" : "what are",
"what's" : "what is",
"what've" : "what have",
"where's" : "where is",
"who'd" : "who would",
"who'll" : "who will",
"who're" : "who are",
"who's" : "who is",
"who've" : "who have",
"won't" : "will not",
"wouldn't" : "would not",
"you'd" : "you would",
"you'll" : "you will",
"you're" : "you are",
"you've" : "you have",
"'re": " are",
"wasn't": "was not",
"we'll":" will",
"didn't": "did not"
}

# %%
#Putting these 2 columns into X and y to send for splitting
X = data['Review'].copy()

#Cleaning and Filtering of Data
nlp = spacy.load('en_core_web_sm',disable=['parser','ner'])
stop = stopwords.words('english')
def cleanData(reviews):
    all_=[]
    for review in reviews:
        lower_case = review.lower() #lower case the text
        lower_case = lower_case.replace(" n't"," not") #correct n't as not
        lower_case = lower_case.replace("."," . ")
        lower_case = ' '.join(word.strip(string.punctuation) for word in lower_case.split()) #remove punctuation
        words = lower_case.split() #split into words
        words = [word for word in words if word.isalpha()] #remove numbers
        split = [apposV2[word] if word in apposV2 else word for word in words] #correct using apposV2 as mentioned above
        split = [appos[word] if word in appos else word for word in split] #correct using appos as mentioned above
        split = [word for word in split if word not in stop] #remove stop words
        reformed = " ".join(split) #join words back to the text
        doc = nlp(reformed)
        reformed = " ".join([token.lemma_ for token in doc]) #lemmatiztion
        all_.append(reformed)
    df_cleaned = pd.DataFrame()
    df_cleaned['clean_reviews'] = all_
    return df_cleaned['clean_reviews']
X_cleaned = cleanData(X)
data.drop(['Review'], axis=1)
data["Review"]=X_cleaned
display(X_cleaned)
# Out:
# 0        fan walk dead ever since first episode first s...
# 1        fan walk dead ever since first episode first s...
# 2        would put series top time despite last series ...
# 3        first thing say normally zombie movie series f...
# 4        everyone know walk dead good use early season ...
#                                ...
# 52077    another beautiful meaningful animation genius ...
# 52078                 enjoy read review please follow blog
# 52079    joe voice jamie foxx jazz musician teach middl...
# 52080    never think would ever watch film disney spiri...
# 52081    lucky enough see london film festival film pre...
# Name: clean_reviews, Length: 52082, dtype: object

# %%
data.to_csv("Data/rev.csv", index=False)
data.head()
# Out:
#    Rating                                             Review
# 0       9  fan walk dead ever since first episode first s...
# 1       9  fan walk dead ever since first episode first s...
# 2       9  would put series top time despite last series ...
# 3       9  first thing say normally zombie movie series f...
# 4       9  everyone know walk dead good use early season ...
